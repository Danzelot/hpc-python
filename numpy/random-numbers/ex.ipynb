# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as r

# %%
ran = np.random.random(size=(1000))

# %%
uni = np.random.uniform(size=(1000))

# %%
nor = np.random.normal(size=(1000))

# %%
for random in [r.random, r.uniform, r.normal]:
    x = random(size=(1000))
    print(np.mean(x), np.std(x))
    plt.hist(x,50)
    plt.show()
# Out:
# 0.5117979609669034 0.2874866084602315
# 0.4877417131417137 0.2840498718035923
# 0.03555331373399843 1.00680838982224
